# %% [markdown]
# <a href="https://colab.research.google.com/github/farkhad-gazizov/educational/blob/main/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%D0%BF%D0%BE_%D1%82%D0%B5%D0%BC%D0%B5_%C2%AB%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D1%8B_Python%C2%BB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание по теме «Основы Python»

# %% [markdown]
# Задание 1.
# Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
# Напишите код, который проверяет какая из этих строк длиннее.

# %%
phrase_1, phrase_2 = input('Введите фразу 1: '), input('Введите фразу 2: ')
if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее фразы 2')
elif len(phrase_2) > len(phrase_1):
    print('Фраза 2 длиннее фразы 1')
else:
    print('Фразы равной длины')
# Out:
# Введите фразу 1: Пайтон - лучший язык программирования для аналитиков!
# Введите фразу 2: У Пайтона простой синтаксис
# Фраза 1 длиннее фразы 2

# %% [markdown]
# Задание 2.
# Дана переменная, в которой хранится число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным

# %%
year = int(input('Введите год: '))
if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print('Високосный год')
else:
    print('Обычный год')
# Out:
# Введите год: 100
# Обычный год

# %% [markdown]
# Задание 3.
# Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.

# %%
day = int(input('Введите день: '))
month = input('Введите месяц: ')
month = month.lower()  # приведение к нижнему регистру - на случай, если пользователь введет слово с разными регистрами
if (month == 'март' and day >= 21) or (month == 'апрель' and day <= 20):
    zodiaс = 'Овен'
elif (month == 'апрель' and day >= 21) or (month == 'май' and day <= 20):
    zodiaс = 'Телец'
elif (month == 'май' and day >= 21) or (month == 'июнь' and day <= 21):
    zodiaс = 'Близнецы'
elif (month == 'июнь' and day >= 22) or (month == 'июль' and day <= 22):
    zodiaс = 'Рак'
elif (month == 'июль' and day >= 23) or (month == 'август' and day <= 22):
    zodiaс = 'Лев'
elif (month == 'август' and day >= 23) or (month == 'сентябрь' and day <= 23):
    zodiaс = 'Дева'
elif (month == 'сентябрь' and day >= 24) or (month == 'октябрь' and day <= 23):
    zodiaс = 'Весы'
elif (month == 'октябрь' and day >= 24) or (month == 'ноябрь' and day <= 22):
    zodiaс = 'Скорпион'
elif (month == 'ноябрь' and day >= 23) or (month == 'декабрь' and day <= 21):
    zodiaс = 'Стрелец'
elif (month == 'декабрь' and day >= 22) or (month == 'январь' and day <= 20):
    zodiaс = 'Козерог'
elif (month == 'январь' and day >= 21) or (month == 'февраль' and day <= 18):
    zodiaс = 'Водолей'
elif (month == 'февраль' and day >= 19) or (month == 'март' and day <= 20):
    zodiaс = 'Водолей'
print('Ваш знак зодиака:', zodiaс)
# Out:
# Введите день: 16
# Введите месяц: Октябрь
# Ваш знак зодиака: Весы

# %%
# вариант от преподавателя с оптимизацией (использование словарей) - изучить!
signs = {"март": (21, "Рыбы", "Овен"), "апрель": (21, "Овен", "Телец"), "май": (22, "Телец", "Близнецы"),
        "июнь": (22, "Близнецы", "Рак"), "июль": (23, "Рак", "Лев"), "август": (24, "Лев", "Дева"),
        "сентябрь": (24, "Дева", "Весы"), "октябрь": (24, "Весы", "Скорпион"),
        "ноябрь": (23, "Скорпион", "Стрелец"), "декабрь": (23, "Стрелец", "Козерог"),
        "январь": (21, "Козерог", "Водолей"), "февраль": (20, "Водолей","Рыбы")}
day, month = int(input("Введите день")), input("Введите месяц")
print(signs[month][2]) if (day >= signs[month][0]) else print(signs[month][1])
# Out:
# Введите день16
# Введите месяцоктябрь
# Весы

# %% [markdown]
# Задание 4.
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры (ширина, длина, высота) хранятся в переменных (в сантиметрах):
#
# Используйте следующие правила:
#
# если каждое из трех измерений менее или равно 15 сантиметрам, то выведите на экран "Коробка №1";
# если хотя бы одно из измерений больше 2 метров, то выводите "Упаковка для лыж";
# если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите "Коробка №2";
# во всех остальных случаях выводите "Коробка №3".

# %%
width = int(input('Введите ширину в см: '))
length = int(input('Введите длину в см: '))
height = int(input('Введите высоту в см: '))
if width <= 15 and length <= 15 and height <= 15:
    print('Коробка №1')
elif width > 200 or length > 200 or height > 200:
    print('Упаковка для лыж')
elif (15 < width < 50) or (15 < length < 50) or (15 < height < 50):
    print('Коробка №2')
else:
    print('Коробка №3')
# Out:
# Введите ширину в см: 45
# Введите длину в см: 55
# Введите высоту в см: 65
# Коробка №2

# %% [markdown]
# Задание 5 (необязательное).
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет "счастливым". Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.

# %%
number = int(input('Введите номер проездного билета (6 цифр): '))
digit6 = number % 10
digit5 = (number // 10) % 10
digit4 = (number // 100) % 10
digit3 = (number // 1000) % 10
digit2 = (number // 10000) % 10
digit1 = number // 100000
sum1 = digit1 + digit2 + digit3
sum2 = digit4 + digit5 + digit6
if sum1 == sum2:
    print('Счастливый билет')
else:
    print('Несчастливый билет')
# Out:
# Введите номер проездного билета (6 цифр): 756576
# Счастливый билет

# %% [markdown]
# Задание 6 (необязательное).
# Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник). Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#
# если пользователь выбрал круг, запрашиваем его радиус,
# если треугольник – длины трех его сторон;
# если прямоугольник – длины двух его сторон.

# %%
import math  # импорт библиотеки math для использования функции sqrt() - извлечение квадратного корня

# %%
shape_type = input('Введите тип фигуры: ')
shape_type = shape_type.lower()  # приведение к нижнему регистру - на случай, если пользователь введет слово с разными регистрами
if shape_type == 'круг':
    radius = int(input('Введите радиус круга: '))
    print('Площадь круга: ', 3.14159 * radius ** 2)
elif shape_type == 'треугольник':
    a = int(input('Введите длину стороны А: '))
    b = int(input('Введите длину стороны B: '))
    c = int(input('Введите длину стороны C: '))
    p = (a + b + c) / 2  # вычисление полупериметра
    print('Площадь треугольника: ', math.sqrt(p * (p - a) * (p - b) * (p - c)))  # вычисление по формуле Герона
elif shape_type == 'прямоугольник':
    a = int(input('Введите длину стороны А: '))
    b = int(input('Введите длину стороны B: '))
    print('Площадь прямоугольника: ', a * b)
# Out:
# Введите тип фигуры: прямоугольник
# Введите длину стороны А: 3
# Введите длину стороны B: 4
# Площадь прямоугольника:  12

# %% [markdown]
# **Фархад, добрый день!**
#
# **Спасибо, работа хорошая, реализации задач корректные.**
#
# **Замечательно, что взялись за доп. задания)**
#
# **Если интересно, то чуть забегая вперед и используя словари для задачи со знаками зодиака, ее можно оптимизировать вот так:**

# %%
signs = {"март": (21, "Рыбы", "Овен"), "апрель": (21, "Овен", "Телец"), "май": (22, "Телец", "Близнецы"),
        "июнь": (22, "Близнецы", "Рак"), "июль": (23, "Рак", "Лев"), "август": (24, "Лев", "Дева"),
        "сентябрь": (24, "Дева", "Весы"), "октябрь": (24, "Весы", "Скорпион"),
        "ноябрь": (23, "Скорпион", "Стрелец"), "декабрь": (23, "Стрелец", "Козерог"),
        "январь": (21, "Козерог", "Водолей"), "февраль": (20, "Водолей","Рыбы")}


day, month = int(input("Введите день")), input("Введите месяц")
print(signs[month][2]) if (day >= signs[month][0]) else print(signs[month][1])
# Out:
# Введите день16
# Введите месяцоктябрь
# Весы
